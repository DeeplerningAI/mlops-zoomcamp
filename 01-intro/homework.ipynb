# %%
# !python --version
# Out:
# Python 3.9.23

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/mlops-zoomcamp/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/mlops-zoomcamp/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 45.5 MB/s  0:00:00s eta 0:00:01
# Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 55.7 MB/s  0:00:00s eta 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]━━━━ 3/4 [pandas]
# Successfully installed numpy-2.0.2 pandas-2.3.2 pytz-2025.2 tzdata-2025.2

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/envs/mlops-zoomcamp/lib/python3.9/site-packages (from scikit-learn) (2.0.2)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 51.9 MB/s  0:00:00s eta 0:00:01
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 50.5 MB/s  0:00:00s eta 0:00:010:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# Successfully installed joblib-1.5.2 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.6.1'

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /opt/conda/envs/mlops-zoomcamp/lib/python3.9/site-packages (21.0.0)

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         17.7    1.0      0.5        0.00           0.0
# 1             1         10.0    3.5      0.5        3.75           0.0
# 2             1         23.3    3.5      0.5        3.00           0.0
# 3             1         10.0    3.5      0.5        2.00           0.0
# 4             1          7.9    3.5      0.5        3.20           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         22.70                   2.5          0.0
# 1                    1.0         18.75                   2.5          0.0
# 2                    1.0         31.30                   2.5          0.0
# 3                    1.0         17.00                   2.5          0.0
# 4                    1.0         16.10                   2.5          0.0

# %%
df.describe(include='all')
# Out:
#             VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count   2.964624e+06                     2964624                     2964624
# unique           NaN                         NaN                         NaN
# top              NaN                         NaN                         NaN
# freq             NaN                         NaN                         NaN
# mean    1.754204e+00  2024-01-17 00:46:36.431092  2024-01-17 01:02:13.208130
# min     1.000000e+00         2002-12-31 22:59:39         2002-12-31 23:05:41
# 25%     2.000000e+00  2024-01-09 15:59:19.750000         2024-01-09 16:16:23
# 50%     2.000000e+00  2024-01-17 10:45:37.500000  2024-01-17 11:03:51.500000
# 75%     2.000000e+00  2024-01-24 18:23:52.250000         2024-01-24 18:40:29
# max     6.000000e+00         2024-02-01 00:01:15         2024-02-02 13:56:52
# std     4.325902e-01                         NaN                         NaN
#
#         passenger_count  trip_distance    RatecodeID store_and_fwd_flag  \
# count      2.824462e+06   2.964624e+06  2.824462e+06            2824462
# unique              NaN            NaN           NaN                  2
# top                 NaN            NaN           NaN                  N
# freq                NaN            NaN           NaN            2813126
# mean       1.339281e+00   3.652169e+00  2.069359e+00                NaN
# min        0.000000e+00   0.000000e+00  1.000000e+00                NaN
# 25%        1.000000e+00   1.000000e+00  1.000000e+00                NaN
# 50%        1.000000e+00   1.680000e+00  1.000000e+00                NaN
# 75%        1.000000e+00   3.110000e+00  1.000000e+00                NaN
# max        9.000000e+00   3.127223e+05  9.900000e+01                NaN
# std        8.502817e-01   2.254626e+02  9.823219e+00                NaN
#
#         PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count   2.964624e+06  2.964624e+06  2.964624e+06  2.964624e+06  2.964624e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    1.660179e+02  1.651167e+02  1.161271e+00  1.817506e+01  1.451598e+00
# min     1.000000e+00  1.000000e+00  0.000000e+00 -8.990000e+02 -7.500000e+00
# 25%     1.320000e+02  1.140000e+02  1.000000e+00  8.600000e+00  0.000000e+00
# 50%     1.620000e+02  1.620000e+02  1.000000e+00  1.280000e+01  1.000000e+00
# 75%     2.340000e+02  2.340000e+02  1.000000e+00  2.050000e+01  2.500000e+00
# max     2.650000e+02  2.650000e+02  4.000000e+00  5.000000e+03  1.425000e+01
# std     6.362391e+01  6.931535e+01  5.808686e-01  1.894955e+01  1.804102e+00
#
#              mta_tax    tip_amount  tolls_amount  improvement_surcharge  \
# count   2.964624e+06  2.964624e+06  2.964624e+06           2.964624e+06
# unique           NaN           NaN           NaN                    NaN
# top              NaN           NaN           NaN                    NaN
# freq             NaN           NaN           NaN                    NaN
# mean    4.833823e-01  3.335870e+00  5.270212e-01           9.756319e-01
# min    -5.000000e-01 -8.000000e+01 -8.000000e+01          -1.000000e+00
# 25%     5.000000e-01  1.000000e+00  0.000000e+00           1.000000e+00
# 50%     5.000000e-01  2.700000e+00  0.000000e+00           1.000000e+00
# 75%     5.000000e-01  4.120000e+00  0.000000e+00           1.000000e+00
# max     4.000000e+00  4.280000e+02  1.159200e+02           1.000000e+00
# std     1.177600e-01  3.896551e+00  2.128310e+00           2.183645e-01
#
#         total_amount  congestion_surcharge   Airport_fee
# count   2.964624e+06          2.824462e+06  2.824462e+06
# unique           NaN                   NaN           NaN
# top              NaN                   NaN           NaN
# freq             NaN                   NaN           NaN
# mean    2.680150e+01          2.256122e+00  1.411611e-01
# min    -9.000000e+02         -2.500000e+00 -1.750000e+00
# 25%     1.538000e+01          2.500000e+00  0.000000e+00
# 50%     2.010000e+01          2.500000e+00  0.000000e+00
# 75%     2.856000e+01          2.500000e+00  0.000000e+00
# max     5.000000e+03          2.500000e+00  1.750000e+00
# std     2.338558e+01          8.232747e-01  4.876239e-01

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /opt/conda/envs/mlops-zoomcamp/bin/python
# 3.9.23 (main, Jun  5 2025, 13:40:20)
# [GCC 11.2.0]
